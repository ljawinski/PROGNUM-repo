# %% [markdown]
# Answers for Week 1
# * Name: Leonie Jawinski
# * Username: ljawinski
# * Student s-number:S6375839
# * Group: AS4

# %%
from scipy.constants import G, pi
G=G
pi=pi
P=3.154E7
a=1.496E11
M=(4*pi*a**3)/(P**2*G)
print (M, "m")
# Out:
# 6.336880873908588e+29 m

# %% [markdown]
# Task 1.19
# What is the meaning of wildcard *?
# any charatcters except slah and the first dot of a hidden file
# 1. lists all files with the given conditions
# * :all characters
# 0-9: any characters ranging between o and 9
# [co]: all files ending with c or o
# co: all files ending with co

# %% [markdown]
# Task 1.16
# cd ~/Desktop

# %% [markdown]
# Task 1.15
# 1. what will be the output of Unix command pwd?
# prints the absolute path to current directory
# 2. to which directories refer the notations . and ..?
# . is for the current directory
# .. is for the parent directory

# %%
from scipy.constants import G
G=G
m=7.342*10E22
M=5.9722*10E24
r=385000.6*10E3
F=(G*M*m)/r**2
print(F)
# Out:
# 1.9743840518075715e+20

# %% [markdown]
# x=22/7

# %% [markdown]
# $$y=\frac{sin(X)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub
